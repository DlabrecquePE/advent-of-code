# %%
import os

# %%
file = 'data/day07.txt'
path = os.path.join(os.getcwd(), file)
with open(path, 'r') as fp:
    lines = [x.rstrip() for x in fp.readlines()]

# %%
class Bag:
    def __init__(self, color, ):
        pass

# %%
for line in lines:
    bag, rules = line.split(' bags contain ')
    rules = rules.strip(' bags.').strip(' bag.')
    rules = rules.replace(' bag, ', ' bags, ')
    rules = [] if rules == 'no other' else rules.split(' bags, ')
    bag_dict[bag] = rules.split
bag_dict = {num: bag for num, bag in rule.split(' ', 1) for rule in rules}

# %%
# part one
target = 'shiny gold'
contains_set, candidate_set = set(), set(inner_bags_dict.keys())
new_contains_set = {target}
while new_contains_set:
    contains_set.update(new_contains_set)
    candidate_set -= new_contains_set
    new_contains_set = set()
    for bag in candidate_set:
        inner_bags_set = set(inner_bags_dict[bag].keys())
        contains_target = inner_bags_set.intersection(contains_set)
        if contains_target:
            new_contains_set.add(bag)

t_check = set(inner_bags_dict[target].keys()).intersection(contains_set)
bag_total = len(inner_bags_dict) - len(candidate_set)
total_contains = bag_total if t_check else bag_total - 1
print(total_contains)
# Out:
# 96
