# %%
import os
import numpy as np

# %%
file = 'data/day17.txt'
path = os.path.join(os.getcwd(), file)
with open(path, 'r') as fp:
    line = x.rstrip() for x in fp.readline()

# %%
parse = line.lstrip('target area: x=').replace(', y=', ',').replace('..', ',')
x1, x2, y1, y2 = parse
